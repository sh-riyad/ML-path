# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('flights')
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.shape
# Out:
# (144, 3)

# %%
# converting dataset into time series data
df['datetime'] = pd.to_datetime('01'+ '-' + df['month'].astype(str) + '-' + df['year'].astype(str))
df.set_index('datetime',inplace=True)
df.head()
# Out:
#             year month  passengers
# datetime
# 1949-01-01  1949   Jan         112
# 1949-02-01  1949   Feb         118
# 1949-03-01  1949   Mar         132
# 1949-04-01  1949   Apr         129
# 1949-05-01  1949   May         121

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data = df, x = df.index, y='passengers')
plt.show()

# here the dataset is tread data as it increasing

# %% [markdown]
# #### Now we have to check if the data is stationary or not

# %% [markdown]
# ### Rolling Statistics

# %%
df['rollmean'] = df['passengers'].rolling(window=12).mean()
df['rollstd'] = df['passengers'].rolling(window=12).std()
df.head()
# Out:
#             year month  passengers  rollmean  rollstd
# datetime
# 1949-01-01  1949   Jan         112       NaN      NaN
# 1949-02-01  1949   Feb         118       NaN      NaN
# 1949-03-01  1949   Mar         132       NaN      NaN
# 1949-04-01  1949   Apr         129       NaN      NaN
# 1949-05-01  1949   May         121       NaN      NaN

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df,x=df.index,y=df.passengers)
sns.lineplot(data=df,x=df.index,y=df.rollmean)
sns.lineplot(data=df,x=df.index,y=df.rollstd)
plt.legend(['Passengers','Rolling Mean','Rolling std'])
plt.show()

# %% [markdown]
# <strong>Here Rolling std is approximately stationary but the mean is showing trend pattern and it is increasing by time. That means our data is not stationary </strong>

# %% [markdown]
# ### ADF (Augmented Dickey-Fuller test)
# #####  If Test statistics < Critical Values then the data is stationary

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adf = adfuller(df['passengers'],autolag='AIC')
adf
# Out:
# (0.8153688792060482,
#  0.991880243437641,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.692930839019)

# %%
# These are test statistics
adf[0:4]
# Out:
# (0.8153688792060482, 0.991880243437641, 13, 130)

# %%
stats = pd.Series(adf[0:4],index=['Test Statistic','P-value','#lags used', 'Number if observations used'])
stats
# Out:
# Test Statistic                   0.815369
# P-value                          0.991880
# #lags used                      13.000000
# Number if observations used    130.000000
# dtype: float64

# %%
# These are Critical Values
adf[4]
# Out:
# {'1%': -3.4816817173418295,
#  '5%': -2.8840418343195267,
#  '10%': -2.578770059171598}

# %%
for key, value in adf[4].items():
    print('Criticality', key, ':' , value)
# Out:
# Criticality 1% : -3.4816817173418295
# Criticality 5% : -2.8840418343195267
# Criticality 10% : -2.578770059171598

# %% [markdown]
# #### Here the critical value is less than test statistics value so clearly the dataset is not stationary

# %% [markdown]
# ## Making Data Stationary

# %%
# function to checking stationarity
def test_stationarity(dataframe, col, testName):
    dataframe['rollingMean'] = dataframe[col].rolling(window=12).mean()
    dataframe['rollingStd'] = dataframe[col].rolling(window=12).std()

    adf = adfuller(dataframe[col], autolag='AIC')
    statis = pd.Series(adf[0:4],index=['Test Statistics', 'P-value','#lags used','Number of observation'])
    print(statis)
    for key, val in adf[4].items():
        print(f"{key} : {val}")

    plt.figure(figsize=(8,5))
    plt.title(f"{testName} Transformation")
    sns.lineplot(data = dataframe,x=dataframe.index,y=col)
    sns.lineplot(data=dataframe,x=dataframe.index,y='rollingMean')
    sns.lineplot(data=dataframe,x=dataframe.index,y='rollingStd')
    plt.legend([col,'Rolling Mean','Rolling Std'])
    plt.show()

# %%
test_stationarity(df, 'passengers', 'No')
# Out:
# Test Statistics            0.815369
# P-value                    0.991880
# #lags used                13.000000
# Number of observation    130.000000
# dtype: float64
# 1% : -3.4816817173418295
# 5% : -2.8840418343195267
# 10% : -2.578770059171598

# %%
# Taking a clean dataFrame
flights = df[['passengers']]
flights.head()
# Out:
#             passengers
# datetime
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# ### Applying Shift Transformation

# %%
flights['shift'] = flights['passengers'].shift() #shifting by one month
flights['shiftDiff'] = flights['passengers'] - flights['shift']

test_stationarity(flights.dropna(), 'shiftDiff', 'Shift') 
# Here the first row will contain NaN value so we have to drop that
# Out:
# C:\Users\saraw\AppData\Local\Temp\ipykernel_3620\1882267767.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flights['shift'] = flights['passengers'].shift() #shifting by one month
# C:\Users\saraw\AppData\Local\Temp\ipykernel_3620\1882267767.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flights['shiftDiff'] = flights['passengers'] - flights['shift']
# C:\Users\saraw\AppData\Local\Temp\ipykernel_3620\578227325.py:3: SettingWithCopyWarning:
# ...

# %% [markdown]
# ### Log Transformation

# %%
flights['log'] = np.log(flights['passengers'])

test_stationarity(flights,'log', 'Log')
# Out:
# C:\Users\saraw\AppData\Local\Temp\ipykernel_3620\845279944.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flights['log'] = np.log(flights['passengers'])
# C:\Users\saraw\AppData\Local\Temp\ipykernel_3620\578227325.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['rollingMean'] = dataframe[col].rolling(window=12).mean()
# C:\Users\saraw\AppData\Local\Temp\ipykernel_3620\578227325.py:4: SettingWithCopyWarning:
# ...

# %% [markdown]
# ### Applying sqrt() Transformation

# %%
flights['sqrt'] = np.sqrt(flights['passengers'])

test_stationarity(flights, 'sqrt', 'Square Root')
# Out:
# Test Statistics           -0.345854
# P-value                    0.918754
# #lags used                13.000000
# Number of observation    130.000000
# dtype: float64
# 1% : -3.4816817173418295
# 5% : -2.8840418343195267
# 10% : -2.578770059171598

# %% [markdown]
# ### Applying Cbrt transformation

# %%
flights['cbrt'] = np.cbrt(flights['passengers'])
test_stationarity(flights, 'cbrt', 'Cube Root')
# Out:
# Test Statistics           -0.810035
# P-value                    0.816157
# #lags used                13.000000
# Number of observation    130.000000
# dtype: float64
# 1% : -3.4816817173418295
# 5% : -2.8840418343195267
# 10% : -2.578770059171598

# %% [markdown]
# ### Multiple combination

# %%
flights['log_sqrt'] = np.sqrt(flights['log'])

test_stationarity(flights, 'log_sqrt', 'Log Sqrt')
# Out:
# Test Statistics           -1.942528
# P-value                    0.312326
# #lags used                13.000000
# Number of observation    130.000000
# dtype: float64
# 1% : -3.4816817173418295
# 5% : -2.8840418343195267
# 10% : -2.578770059171598

# %%
flights['logSqrt_shiftDiff'] = flights['log_sqrt'] - flights['log_sqrt'].shift()

test_stationarity(flights.dropna(), 'logSqrt_shiftDiff', 'Log Sqrt Shift Diff')
# Out:
# C:\Users\saraw\AppData\Local\Temp\ipykernel_3620\578227325.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['rollingMean'] = dataframe[col].rolling(window=12).mean()
# C:\Users\saraw\AppData\Local\Temp\ipykernel_3620\578227325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['rollingStd'] = dataframe[col].rolling(window=12).std()
# Test Statistics           -3.079116
# P-value                    0.028138
# #lags used                13.000000
# ...

# %% [markdown]
# #### Here using Log, Sqrt and Shift diff we find the best stationary data

# %% [markdown]
# <h1>First we will implement ARIMA using the original data</h1>

# %%
# making copy of data using deep= True so the the transform data stay unchanged
airPlane = flights[['passengers']].copy(deep=True) ## use 2D for taking data with index and col name
airPlane.head()
# Out:
#             passengers
# datetime
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# <ol>
#     <li>
#          Here as we saw that the data is having trend pattern as well as seasonality and the seasonality is on 12 month. So we will differentiate by 12 month.  It will help to reducing seasonality
#     </li>
#     <li>
#          We also differentiate by 1 month
#     </li>
# </ol>

# %%
airPlane['diff1'] = airPlane['passengers'].diff()
airPlane['diff12'] = airPlane['passengers'].diff(12)
airPlane.head()
# Out:
#             passengers  diff1  diff12
# datetime
# 1949-01-01         112    NaN     NaN
# 1949-02-01         118    6.0     NaN
# 1949-03-01         132   14.0     NaN
# 1949-04-01         129   -3.0     NaN
# 1949-05-01         121   -8.0     NaN

# %% [markdown]
# ## ARIMA model

# %%
# import airma model
import statsmodels
from statsmodels.tsa.arima.model import ARIMA

# import ploting packages for Auto regressive and moving avarage
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# <h1>For orginal passengers data </h1>

# %%
plot_pacf(airPlane['passengers'],lags=50);
# here 1 one is outside of the significant area

# %%
plot_acf(airPlane['passengers'],lags=50);

# %% [markdown]
# <h1>For diff1 </h1>

# %%
plot_pacf(airPlane['diff1'].dropna(),lags=50);

# %%
plot_acf(airPlane['diff1'].dropna(), lags=50);

# %% [markdown]
# here from the graphs we can use p=1, q=3 and d=1

# %%
# test-train split
train = airPlane[:round(len(airPlane)*70/100)]
test = airPlane[round(len(airPlane)*70/100):]
print(train.tail(2))
print(test.head(2))
# Out:
#             passengers  diff1  diff12
# datetime
# 1957-04-01         348   -8.0    35.0
# 1957-05-01         355    7.0    37.0
#             passengers  diff1  diff12
# datetime
# 1957-06-01         422   67.0    48.0
# 1957-07-01         465   43.0    52.0

# %%
# training the model 
model =  ARIMA(train['passengers'], order=(1,1,3))
model_fit= model.fit()
prediction = model_fit.predict(start = test.index[0], end= test.index[-1])
# Out:
# C:\Users\saraw\miniconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\saraw\miniconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\saraw\miniconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
airPlane['arimaPred'] = prediction
airPlane.tail(10)
# Out:
#             passengers  diff1  diff12   arimaPred
# datetime
# 1960-03-01         419   28.0    13.0  341.111333
# 1960-04-01         461   42.0    65.0  341.111333
# 1960-05-01         472   11.0    52.0  341.111333
# 1960-06-01         535   63.0    63.0  341.111333
# 1960-07-01         622   87.0    74.0  341.111333
# 1960-08-01         606  -16.0    47.0  341.111333
# 1960-09-01         508  -98.0    45.0  341.111333
# 1960-10-01         461  -47.0    54.0  341.111333
# 1960-11-01         390  -71.0    28.0  341.111333
# 1960-12-01         432   42.0    27.0  341.111333

# %%
sns.lineplot(data=airPlane,x=airPlane.index, y='passengers')
sns.lineplot(data=airPlane,x=airPlane.index,y='arimaPred')
plt.show()

# %%
# Checking error
from sklearn.metrics import mean_squared_error

np.sqrt(mean_squared_error(test['passengers'], prediction))
# Out:
# 111.1101033142743

# %%
plot_pacf(airPlane['arimaPred'].dropna(),lags=20);
plot_acf(airPlane['arimaPred'].dropna(),lags=20);

# %% [markdown]
# <h3>Using the diff12 feature</h3>

# %%
plot_pacf(airPlane['diff12'].dropna(),lags=50);

# %%
plot_acf(airPlane['diff12'].dropna(),lags=50);

# %% [markdown]
# <h1>Making seasonal ARIMA model</h1>

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
sModel = SARIMAX(train['passengers'],order=(1,1,3),seasonal_order=(1,1,4,12))
sModel_fit = sModel.fit()
sPrediction = sModel_fit.predict(start=test.index[0], end=test.index[-1])
airPlane['arimaxPred'] = sPrediction
# Out:
# C:\Users\saraw\miniconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\saraw\miniconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\saraw\miniconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
airPlane.tail(10)
# Out:
#             passengers  diff1  diff12   arimaPred  arimaxPred
# datetime
# 1960-03-01         419   28.0    13.0  341.111333  481.465377
# 1960-04-01         461   42.0    65.0  341.111333  478.710796
# 1960-05-01         472   11.0    52.0  341.111333  489.018733
# 1960-06-01         535   63.0    63.0  341.111333  554.458029
# 1960-07-01         622   87.0    74.0  341.111333  612.474303
# 1960-08-01         606  -16.0    47.0  341.111333  596.691913
# 1960-09-01         508  -98.0    45.0  341.111333  532.438720
# 1960-10-01         461  -47.0    54.0  341.111333  476.865746
# 1960-11-01         390  -71.0    28.0  341.111333  429.480591
# 1960-12-01         432   42.0    27.0  341.111333  474.726328

# %%
sns.lineplot(data=airPlane,x=airPlane.index,y='passengers')
sns.lineplot(data=airPlane,x=airPlane.index,y='arimaxPred')
sns.lineplot(data=airPlane,x=airPlane.index,y='arimaPred')
plt.show()

# %%
# Calculating Error
np.sqrt(mean_squared_error(test['passengers'], sPrediction))
# Out:
# 26.519908458438458

# %% [markdown]
# <h1>Predicting for future data</h1>

# %%
airPlane.tail(1)
# Out:
#             passengers  diff1  diff12   arimaPred  arimaxPred
# datetime
# 1960-12-01         432   42.0    27.0  341.111333  474.726328

# %%
## Generating dates 
future_dates = pd.DataFrame(pd.date_range(start = '1961-01-01', end= '1961-12-01', freq='MS'),columns=['Dates'])
future_dates.set_index('Dates',inplace=True)
future_dates.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [1961-01-01 00:00:00, 1961-02-01 00:00:00, 1961-03-01 00:00:00, 1961-04-01 00:00:00, 1961-05-01 00:00:00]

# %%
futurePred = sModel_fit.predict(start = future_dates.index[0],end=future_dates.index[-1])
future_dates['pred'] = futurePred

# %%
sns.lineplot(data=airPlane,x=airPlane.index,y='passengers')
sns.lineplot(data=airPlane,x=airPlane.index,y='arimaxPred')
sns.lineplot(data=future_dates,x=future_dates.index,y='pred')
plt.show()
